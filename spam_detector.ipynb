# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# I predict that the **Logistical Regression Model** will be the best fit for this data set because it is more efficient and easier to interpret than the Random Forest model. It is important to be able to quickly identify spam so that it can be removed from email inboxes before individuals encounter them or act on them.
#
# ##### Note: I used ChatGPT to help me with this response - to compare and contrast Random Forest and Linear Regression models. I also had a Tutoring appointment where we discussed the various models.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# I used the Google Colab AI Generator to help me with this code
# prompt: # Create the labels set `y` and features DataFrame `X`

y = data['spam']
X = data.drop('spam', axis=1)

# %%
# I used the Google Colab AI Generator to help me with this code
# prompt: # Check the balance of the labels variable (`y`) by using the `value_counts` function.

print(y.value_counts())
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# I used the Google Colab AI Generator to help me with this code
# prompt: # Split the data into X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

X_train.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 4576            0.00                0.0           0.00           0.0
# 4401            0.00                0.0           0.00           0.0
# 3707            0.17                0.0           0.17           0.0
# 2362            0.00                0.0           0.00           0.0
# 1537            0.00                0.0           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 4576           0.00             0.0               0.0                 0.0
# 4401           0.00             0.0               0.0                 0.0
# 3707           0.00             0.0               0.0                 0.0
# 2362           0.00             0.0               0.0                 0.0
# 1537           2.17             0.0               0.0                 0.0
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# ...

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
# I used the Google Colab AI Generator to help me with this code
# prompt: # Create the StandardScaler instance

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
# I used the Google Colab AI Generator to help me with this code
# Working with the tutor the code was refined, adding "_scaled" which was not part of the auto generated code.
# Using just the original code would have caused problems with overwriting.

# prompt: # Fit the Standard Scaler with the training data
X_train_scaled = scaler.fit_transform(X_train)

# I worked with the tutor to better understand the code.
# Displaying the code output helped me better understand the code.
display(X_train.head(1))
X_train_scaled[0]
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 4576             0.0                0.0            0.0           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 4576            0.0             0.0               0.0                 0.0
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# 4576              0.0             0.0  ...                   0.0          0.0
#
#       char_freq_(  char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 4576        0.131          0.0          0.0          0.0          0.0
#
#       capital_run_length_average  capital_run_length_longest  \
# 4576                       1.488                           5
#
#       capital_run_length_total
# 4576                        64
#
# [1 rows x 57 columns]
# array([-0.35811925, -0.16744248, -0.56071981, -0.04464735, -0.45989286,
#        -0.34953634, -0.28922113, -0.25739046, -0.32549439, -0.36823638,
# ...

# %%
# I used the Google Colab AI Generator to help me with this code
# As above, working with the tutor the code was refined, adding "_scaled" which was not part of the auto generated code.
# Using just the original code would have caused problems with overwriting.

# Scale the training data
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
from sklearn.linear_model import LogisticRegression

log_reg_model = LogisticRegression(random_state=1)
log_reg_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
# I used the Google Colab AI Generator to help me with this code
# prompt: # Make and save testing predictions with the saved logistic regression model using the test data
# # Review the predictions


# Make predictions on the test data
y_pred = log_reg_model.predict(X_test_scaled)
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
# I used the Google Colab AI Generator to help me with this code
# I aslo used my tutoring session to better understand the code.
# prompt: # Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.

# Print the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Accuracy: {accuracy}")
# Out:
# Logistic Regression Accuracy: 0.9278887923544744

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# I used the Google Colab AI Generator to help me with this code. I had to work with Xpert to get the code to set the Random State at 1.
# prompt: # Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier

# Create and fit the Random Forest Classifier model
rf_model = RandomForestClassifier(random_state=1)
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
# I used the Google Colab AI Generator to help me with this code
# prompt: # Make and save testing predictions with the saved logistic regression model using the test data
# # Review the predictions

# Make predictions on the test data
y_pred_rf = rf_model.predict(X_test_scaled)

# Review the predictions
y_pred_rf
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
# I used the Google Colab AI Generator to help me with this code
# prompt: # Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.

# Calculate the accuracy score
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest Accuracy: {accuracy_rf}")
# Out:
# Random Forest Accuracy: 0.9669852302345786

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# Both models performed pretty good at greater than 92%, However, the Random Forest model perfomed a little better @  0.9635099913119027 than the Linear Regression Model @ 0.9278887923544744. I think that the RF model performed better at determining whether an email is spam or not because the features are highly complex and variable and the features don't necessarily have a linear relationship between each other. I had predicted that the Linear Regression Model would perform better, but I was wrong. Some of the things to consider when considering which model to use and evaluating the data set you are working with include: Mechanism by which the model works (if it is linear or uses multiple decisions) Interpretability (which is easier to understand) Performance (how well it performs between the features) Efficiency (how many resources it requires to run). So, although the Random Forest performs better, it may be better to acutually use the Linear Regression model because it uses fewer resoureces without a large loss of accuracy.
#
# ##### Note: I used ChatGPT and Xpert Learning to do some research on this topic and in comparing and contrasting Random Forest and Linear Regression. My tutor also helped me better understand these different models.
